# %% [markdown]
# # BL40A2020 Wireless Communication Systems
#
# ## Assignment  week 1: Signals and systems
#
# ## Author: Eero Suomalainen

# %% [markdown]
# *Objective:* The goal of this assignment is to get used to scientific computing using python and its libraries. So, *do not make the calculations by hand*.
#
# *Suggestion:* Follow the lecture notes in GitHub
#
# **Consider the following function $$s (t) = 2 e^{-t} \cos(2\pi t).$$**
#
# **Using sympy (or numpy or scipy), do the following tasks**
#
# - Define the function.

# %%
! pip install --upgrade numpy
! pip install --upgrade matplotlib
! pip install --upgrade sympy
# Out:
# ...
#      |████████████████████████████████| 15.7 MB 4.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 11.2 MB 4.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 965 kB 42.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.2 MB 45.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 73.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 6.4 MB 4.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 532 kB 30.3 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import sympy as sp
sp.init_printing() 
from matplotlib import style
style.use('bmh')
plt.rcParams['figure.figsize'] = 16, 6

# %%
#Define a varible in sympy
t = sp.symbols('t')

# %%
s = 2*sp.exp(-t)*sp.cos(2*sp.pi*t)
s
# Out:
#    -t
# 2⋅ℯ  ⋅cos(2⋅π⋅t)

# %% [markdown]
# - $\mathrm{d}s/\mathrm{d}t$

# %%
s_der = sp.diff(s, t)
s_der
# Out:
#        -t                 -t
# - 4⋅π⋅ℯ  ⋅sin(2⋅π⋅t) - 2⋅ℯ  ⋅cos(2⋅π⋅t)

# %% [markdown]
# - $\int s(t) \mathrm{d}t$

# %%
s_intg = sp.integrate(s, t)
s_intg
# Out:
# 4⋅π⋅sin(2⋅π⋅t)   2⋅cos(2⋅π⋅t)
# ────────────── - ────────────
#   t      2  t     t      2  t
#  ℯ  + 4⋅π ⋅ℯ     ℯ  + 4⋅π ⋅ℯ

# %% [markdown]
# - Plot the three signals together.

# %%
#Previously defined functions are printed so thay can be
#copied to next section to make plots
print(s)
print(s_der)
print(s_intg)
#sp.plot(s,(t,-5,5))
# Out:
# 2*exp(-t)*cos(2*pi*t)
# -4*pi*exp(-t)*sin(2*pi*t) - 2*exp(-t)*cos(2*pi*t)
# 4*pi*sin(2*pi*t)/(exp(t) + 4*pi**2*exp(t)) - 2*cos(2*pi*t)/(exp(t) + 4*pi**2*exp(t))

# %%
t = np.linspace(0, 2, 2000)
plt.figure(figsize=(16,6)) 
plt.plot(t, 10 * np.sin(2*np.exp(-t)*np.cos(2*np.pi*t)), 'r--')
plt.plot(t, 10 * np.cos(-4*np.pi*np.exp(-t)*np.sin(2*np.pi*t) - 2*np.exp(-t)*np.cos(2*np.pi*t)), 'b--')
plt.plot(t, 10 * np.exp(4*np.pi*np.sin(2*np.pi*t)/(np.exp(t) + 4*np.pi**2*np.exp(t)) - 2*np.cos(2*np.pi*t)/(np.exp(t) + 4*np.pi**2*np.exp(t))), 'g--')
#plt.plot(t, 10 * np.sin(s))
#plt.plot(t,2,-2)
plt.xlabel('$t$')
plt.ylabel('$x(t)$')
plt.title(r'Plot signals')
plt.xlim([0, 2])
plt.grid(True)
plt.show()

# %% [markdown]
# - Fourier tranform of $S(w) = \mathcal{F} \left\{s(t) u(t)\right\},$ where $u(t)$ is the step function.

# %%
w = sp.symbols('w')
t = sp.symbols('t')
u = 18*t**2 + 3*t + 5
s_ft = sp.fourier_transform(s * u,t,w)
s_ft
# Out:
#                    ⎛ 2  -t                 ⎞
# 36⋅FourierTransform⎝t ⋅ℯ  ⋅cos(2⋅π⋅t), t, w⎠

# %% [markdown]
# - Plot the real part of $S(w), \; -5 \leq w \leq 5$

# %%
sp.plot(s_ft, (w,-5,5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sympy/plotting/experimental_lambdify.py in __call__(self, args)
#     175             #The result can be sympy.Float. Hence wrap it with complex type.
# --> 176             result = complex(self.lambda_func(args))
#     177             if abs(result.imag) > 1e-7 * abs(result):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sympy/plotting/experimental_lambdify.py in __call__(self, *args, **kwargs)
#     271     def __call__(self, *args, **kwargs):
# --> 272         return self.lambda_func(*args, **kwargs)
#     273
#
# <string> in <lambda>(x0)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sympy/core/expr.py in __complex__(self)
#     349         re, im = result.as_real_imag()
# --> 350         return complex(float(re), float(im))
#     351
#
# ...

# %%
t = np.linspace(-5, 5, 2000)
plt.figure(figsize=(16,16)) 
#plt.subplot(4,1,1); plt.plot(t, (s_ft).real )
sp.plot(s_ft, (w,5,-5))
plt.ylabel('$\mathrm{Re}[x(t)]$')
plt.title(r'Real part of  $s(t)=2e^{t}\cos(2\pi t)$')
plt.grid(True)
plt.xlim([-6, 6])
plt.show()

# %% [markdown]
# - Plot the imaginary part of $S(w), \; -5 \leq w \leq 5$

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,1,2); plt.plot(t, (2*np.exp(-t)*np.cos(2*np.pi*t)).imag )
plt.ylabel('$\mathrm{Im}[x(t)]$')
plt.title(r'Imaginary part of  $s(t)=2e^{t}\cos(2\pi t)$')
plt.grid(True)
plt.xlim([-6, 6])
plt.show()

# %% [markdown]
# - Plot the absolute value of $S(w), \; -5 \leq w \leq 5$

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,1,3); plt.plot(t, np.abs(2*np.exp(-t)*np.cos(2*np.pi*t)) )
plt.ylabel(r'$|x(t)|$')
plt.title(r'Absolute value  of  $s(t)=2e^{t}\cos(2\pi t)$')
plt.grid(True)
plt.xlim([-6, 6])
plt.show()

# %% [markdown]
# - Plot the phase of $S(w), \; -5 \leq w \leq 5$

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,1,4); plt.plot(t, np.angle(2*np.exp(-t)*np.cos(2*np.pi*t)) )
plt.xlabel('$t$')
plt.ylabel(r'$\angle x(t)$')
plt.title(r'Phase value  of  $s(t)=2e^{t}\cos(2\pi t)$');
plt.grid(True)
plt.xlim([-6, 6])
plt.show()
